# %%
import numpy as np
import cvxpy as cvx

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'

# %%
mu = 3
var = 0.5

# %%
plt.plot(gams,qs);
plt.xscale('log');

# %%
n = 100
risks = np.zeros(n)
rets = np.zeros(n)
qs = np.zeros(n)
gams = np.logspace(-2,3,num=n)
for i,gam in enumerate(gams):
    gamma.value = gam
    prob1.solve()
    risks[i] = np.sqrt(risk.value)
    rets[i] = ret.value
    qs[i] = q.value

# %%
plt.plot(rets,risks);
plt.xlabel('Return');
plt.ylabel('Risk');

# %%
plt.plot(gams,qs);
plt.xscale('log');

# %%
X = np.random.randn(100)
Xsq = np.random.randn(100)**2

# %%
plt.scatter(X,(Xsq-Xsq.mean())/Xsq.std());

# %%
mu = np.array([1,-2])
sig1 = 1
sig2 = 4
cor = 0.7
cov = np.array([[sig1**2,cor*sig1*sig2],[cor*sig1*sig2,sig2**2]])
x1,x2 = np.random.multivariate_normal(mu,cov,500).T;
r = (1/3)*x1**2-x2;

# %%
scat = plt.scatter(x1,x2,c=r,cmap='seismic');
plt.colorbar(scat);

# %%
np.linalg.inv(cov)
# Out:
# array([[ 1.96078431, -0.34313725],
#        [-0.34313725,  0.12254902]])

# %%
# Out:
# (2, 1000)
