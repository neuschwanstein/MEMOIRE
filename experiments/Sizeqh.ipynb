# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib as mpl
from matplotlib import rc
rc('text',usetex=True)
rc('font',**{'family':'serif','serif':['Computer Modern Roman']})
import matplotlib.pyplot as plt
% matplotlib inline
% config InlineBackend.figure_format = 'svg'
% config InlineBackend.rc = {'figure.figsize': (5,3.5)}

# %%
import numpy as np
from numpy import sqrt,log,array as ar
import numpy.linalg as la
import cvxpy as cvx
from helper import *
from cd.model.utility import LipschitzExpUtility as leu, RiskNeutralUtility as rnu
from cd.model.distrs import RademacherDistribution,UniformDistribution,NormalDistribution
import cd.model.synth_data as synth
import scaler
from itertools import product

# %%
p = 100
R = NormalDistribution()
Xs = [NormalDistribution() for _ in range(p)]

# %%
M = synth.GaussianMarket(Xs,R,corr_vector=[0 for _ in range(49)]+[1] + [0 for _ in range(50)])
# M = synth.GaussianMarket(Xs,R)
t_true = M.sample_t(50_000)

# %%
qhs = t_true.mean(axis=0)

# %%
qks = np.array([la.norm(qhs[:i])**2 for i in range(1,p+1)])
ps = np.arange(1,p)

# %%
plt.plot(ps,1+(ps-1)/ps*qks[:-1])

# %%
plt.plot(np.arange(1,p+1),qks)

# %%
p = 2
corr_vector = [1/sqrt(p)] * np.ones(p)
# corr_vector = [0 for _ in range(p)]
sig = np.eye(p+1,p+1)
sig[:-1,-1] = corr_vector
sig[1,:-1] = corr_vector
mu = np.zeros(p+1)
Xnr = np.random.multivariate_normal(mu,sig,500)
X0 = Xnr[:,0]
r = Xnr[:,-1]

# %%
plt.scatter(X0,r)
plt.axhline(0)
plt.axvline(0)

# %%
t= X0*r

# %%
t[t<0].var()
# Out:
# 0.43385275196000428

# %%
la.eig([[1,1/sqrt(2)],[1/sqrt(2),1]])
# Out:
# (array([ 1.70710678,  0.29289322]), array([[ 0.70710678, -0.70710678],
#         [ 0.70710678,  0.70710678]]))

# %%
(1+1/sqrt(p))/(1-1/sqrt(p))
# Out:
# 5.828427124746189

# %%
1.70/0.29
# Out:
# 5.862068965517242
