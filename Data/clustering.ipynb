# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import gensim.models.doc2vec as d2v
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = (10,4)
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['font.family'] = 'serif'
matplotlib.rcParams['savefig.dpi'] = 100
plt.rc('text',usetex=True)
plt.rc('font',serif='times')

# %%
from articles import Articles

# %%
model = d2v.Doc2Vec.load('300model')

# %%
ids = [str(a.id) for a in Articles(['id'])]

# %%
data = model.docvecs[ids]

# %%
data.shape
# Out:
# (67094, 300)

# %%
pca_data = PCA(n_components=50).fit_transform(data)

# %%
matplotlib.rcParams['figure.figsize'] = (8,8)
plt.scatter(pca_data[:,0],pca_data[:,1],s=0.1);

# %%
proj_data = TSNE(n_components=2).fit_transform(pca_data)

# %%
4+4

# %%
2+3
